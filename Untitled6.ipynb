# %% [markdown]
# <a href="https://colab.research.google.com/github/rakeshdepati-jpg/Mini-ATM/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("======================================")
print("       WELCOME TO ABC BANK ATM        ")
print("======================================")
class Bank:
  name = ""
  acc_no = 0
  balance = 500
  def set_details(self):
    Bank.name = input("Enter account holder name: ")
    Bank.acc_no = int(input("Enter deposit account number: "))
  def deposit(self):
    amt=int(input("enter deposit amount:"))
    Bank.balance += amt
    print("deposit successful")

  def withdraw(self):
    amt=int(input("enter withdraw amount:"))
    if amt<=Bank.balance:
      Bank.balance -= amt
      print("withdraw successful")
    else:
      print("insufficient balance:")
  def check_balance(self):
    print("Name:",Bank.name);
    print("Account_Number:",Bank.acc_no);
    print("Balance:",Bank.balance);


#-------main program---------
bank = Bank()
bank.set_details()

# ATM Menu using while loop
while True:
  print("\n---- BANK ATM MENU----")
  print("1. deposit")
  print("2. withdraw")
  print("3. check balance")
  print("4. Exit")
  choice = int(input("enter your choice(1-4):"))
  if choice == 1:
    bank.deposit()
  elif choice ==2:
    bank.withdraw()
  elif choice ==3:
    bank.check_balance()
  elif choice ==4:
    print("thank you! visit again")
    break
  else:
    print("Invalid choice")
# Out:
# ...
#        WELCOME TO ABC BANK ATM
# ...
# Enter account holder name: rakesh
# Enter deposit account number: 12345
#
# ---- BANK ATM MENU----
# 1. deposit
# 2. withdraw
# 3. check balance
# 4. Exit
# enter your choice(1-4):1
# enter deposit amount:500
# deposit successful
#
# ---- BANK ATM MENU----
# 1. deposit
# 2. withdraw
# 3. check balance
# 4. Exit
# enter your choice(1-4):2
# enter withdraw amount:400
# withdraw successful
#
# ---- BANK ATM MENU----
# 1. deposit
# 2. withdraw
# 3. check balance
# 4. Exit
# enter your choice(1-4):2
# enter withdraw amount:700
# insufficient balance:
#
# ---- BANK ATM MENU----
# 1. deposit
# 2. withdraw
# 3. check balance
# 4. Exit
# enter your choice(1-4):3
# Name: rakesh
# Account_Number: 12345
# Balance: 600
#
# ---- BANK ATM MENU----
# 1. deposit
# 2. withdraw
# 3. check balance
# 4. Exit
# enter your choice(1-4):4
# thank you! visit again

# %%
class Bank:

# %% [markdown]
# This line creates a class named Bank.
# A class is a blueprint that groups data and functions together.

# %%
def set_details(self):
    Bank.name = input("Enter account holder name: ")
    Bank.acc_no = int(input("Enter deposit account number: "))

# %% [markdown]
# This method is used to take account details from the user and asks the user to enter the account holder’s name and stores it and the user to enter the account number and converts it to integer.

# %%
def deposit(self):
    amt=int(input("enter deposit amount:"))
    Bank.balance += amt
    print("deposit successful")

# %% [markdown]
# This method is used to deposit money into the account and asks the user to enter the deposit amount. after enter the money adds the deposited amount to the existing balance.displays a message after successful deposit.

# %%
def withdraw(self):
    amt=int(input("enter withdraw amount:"))
    if amt<=Bank.balance:
      Bank.balance -= amt
      print("withdraw successful")
    else:
      print("insufficient balance:")

# %% [markdown]
# This method is used to withdraw money from the account and the user to enter the withdrawal amount after condition checks whether sufficient balance is available.if balance is sufficient, subtracts the amount from balance.prints a success message after withdrawal.else block runs if balance is insufficient.and prints insufficient balance

# %%
def check_balance(self):

# %% [markdown]
# it is used to checks the current balance

# %%
bank = Bank()

# %% [markdown]
# This line creates an object of the Bank class.

# %%
bank.set_details()

# %% [markdown]
# This line calls the method to enter name and account number.

# %%
while True:

# %% [markdown]
# This line creates an infinite loop so the ATM menu repeats again and again.

# %%
print("\n---- BANK ATM MENU----")

# %% [markdown]
# This line prints the ATM menu

# %%
print("1. deposit")
print("2. withdraw")
print("3. check balance")
print("4. Exit")

# %% [markdown]
# These lines display the available ATM options.

# %%
choice = int(input("enter your choice(1-4):"))

# %% [markdown]
# This line asks the user to select a menu option.

# %%
if choice == 1:

# %% [markdown]
# Checks if the user selected Deposit.

# %%
bank.deposit()

# %% [markdown]
# Calls the deposit method.

# %%
if choice == 2:

# %% [markdown]
# Checks if the user selected withdraw.

# %%
bank.withdraw()

# %% [markdown]
# Calls the withdraw method.

# %%
if choice == 3:

# %% [markdown]
# Checks if the user selected check balance.

# %%
bank.check_balance

# %% [markdown]
# Calls the check balance method.

# %%
if choice == 4:

# %% [markdown]
# Checks if the user selected exit.

# %%
print("thank you! visit again")

# %% [markdown]
# prints thank you message

# %%
break

# %% [markdown]
# This line stops the while loop and ends the program.

# %%
else:

# %% [markdown]
# This block runs if the user enters an invalid option.

# %%
print("Invalid choice")

# %% [markdown]
# This line prints an error message for wrong input.
